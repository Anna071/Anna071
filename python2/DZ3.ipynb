# %% [markdown]
# ## Домашнее задание
# ### «Функции и работа с данными»

# %% [markdown]
# ### Задание 1**
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
ratings = pd.read_csv ('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
def class_movie (rate):
    if rate <= 2.0:
        class_ = 'Низкий рейтинг'
    elif rate >=4.0:
        class_ ='Высокий рейтинг'
    else:
        class_ = 'Cредний рейтинг'
    return (class_)

# %%
ratings['class']=ratings['rating'].apply(class_movie)
ratings.head()
# Out:
#    userId  movieId  rating   timestamp            class
# 0       1       31     2.5  1260759144  Cредний рейтинг
# 1       1     1029     3.0  1260759179  Cредний рейтинг
# 2       1     1061     3.0  1260759182  Cредний рейтинг
# 3       1     1129     2.0  1260759185   Низкий рейтинг
# 4       1     1172     4.0  1260759205  Высокий рейтинг

# %% [markdown]
# ### Задание 2
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = { ... }
#
# Результат классификации запишите в отдельный столбец region.

# %%
keywords = pd.read_csv ('keywords.csv')
keywords.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = { 'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }

# %%
for region,values in geo_data.items():
    for city in values:
        cities.append(city)
def geo(keyword):
    if keyword in cities:
         for region,values in geo_data.items():
            for city in values:
                if keyword == city:
                    region_key = region
                else:
                    continue
    else: 
        region_key= 'undefined'        
    
    return (region_key)

# %%
keywords['region']=keywords['keyword'].apply(geo)
keywords.head()
# Out:
#          keyword     shows     region
# 0             вк  64292779  undefined
# 1  одноклассники  63810309  undefined
# 2          порно  41747114  undefined
# 3           ютуб  39995567  undefined
# 4      вконтакте  21014195  undefined

# %%
keywords[keywords['region'] != 'undefined'].head(10)
# Out:
#            keyword   shows          region
# 1259        москва  153050           Центр
# 5858   владивосток   43038  Дальний Восток
# 6075     ярославль   41720           Центр
# 8977      мурманск   29984    Северо-Запад
# 9084     хабаровск   29655  Дальний Восток
# 11222        псков   24885    Северо-Запад
# 11785         тула   23898           Центр
# 20823    петербург   14859    Северо-Запад
# 21445      сахалин   14494  Дальний Восток

# %% [markdown]
# ### Задание 3 (бонусное)
#
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл movies.csv и ratings.csv из базы grouplens.org.../movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# - В переменную years запишите список из всех годов с 1950 по 2010.
#
# - Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#
#  - для каждой строки пройдите по всем годам списка years
#  - если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
#  - если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# - Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
# - Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга
#
# P/S/ все файлы находятся в архиве «дополнительные файлы к лекции и дз»

# %%
import numpy as np

# %%
movies = pd.read_csv ('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv ('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head(-50)
# Out:
#        userId  movieId  rating   timestamp  \
# 0           1       31     2.5  1260759144
# 1           1     1029     3.0  1260759179
# 2           1     1061     3.0  1260759182
# 3           1     1129     2.0  1260759185
# 4           1     1172     4.0  1260759205
# ...       ...      ...     ...         ...
# 99949     671     2797     4.0  1063500821
# 99950     671     2804     5.0  1064890525
# 99951     671     2858     4.0  1063503841
# 99952     671     2918     4.0  1065149106
# 99953     671     2959     4.0  1064890427
#
#                                                 title  \
# 0                              Dangerous Minds (1995)
# 1                                        Dumbo (1941)
# 2                                     Sleepers (1996)
# 3                         Escape from New York (1981)
# 4      Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# ...                                               ...
# 99949                                      Big (1988)
# 99950                       Christmas Story, A (1983)
# 99951                          American Beauty (1999)
# 99952                 Ferris Bueller's Day Off (1986)
# 99953                               Fight Club (1999)
#
#                                  genres
# 0                                 Drama
# 1      Animation|Children|Drama|Musical
# 2                              Thriller
# 3      Action|Adventure|Sci-Fi|Thriller
# 4                                 Drama
# ...                                 ...
# 99949      Comedy|Drama|Fantasy|Romance
# 99950                   Children|Comedy
# 99951                     Drama|Romance
# 99952                            Comedy
# 99953       Action|Crime|Drama|Thriller
#
# [99954 rows x 6 columns]

# %%
years = str(np.arange(1950, 2010+1))
print (type(years))
# Out:
# <class 'str'>

# %%
def production_year (title):
    if title.split(' ')[-1].replace('(' , '').replace(')' , '') in years:
        year=title.split(' ')[-1].replace('(' , '').replace(')' , '')
    else:
        year = '1900'
    return (year)

# %%
joined['year']=joined['title'].apply(production_year)
joined.head(50)
# Out:
#     userId  movieId  rating   timestamp  \
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
